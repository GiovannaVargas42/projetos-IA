# %% [markdown]
# TRABALHO DISCIPLINA INTELIGÊNCIA ARTIFICIAL APLICADA À CIÊNCIA ANIMAL - CLASSIFICAÇÃO DE RAÇAS BOVINAS EM SUBESPÉCIES

# %% [markdown]
# Imports de pacotes do Python

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Caminhos principais
base_path_taurinos = '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/'
source_dir = os.path.join(base_path_taurinos, 'Cattle/Taurinos')
target_base_dir = os.path.join(base_path_taurinos, 'Images/Taurinos')

# Proporções para train, validation e test
train_ratio = 0.7
validation_ratio = 0.15
test_ratio = 0.15

# Diretórios de destino
train_dir = os.path.join(target_base_dir, 'train')
validation_dir = os.path.join(target_base_dir, 'validation')
test_dir = os.path.join(target_base_dir, 'test')

# Criar diretórios de destino, se não existirem
for directory in [train_dir, validation_dir, test_dir]:
    os.makedirs(directory, exist_ok=True)

# Listar todas as imagens no diretório de origem
images = [img for img in os.listdir(source_dir) if img.lower().endswith(('png', 'jpg', 'jpeg'))]

# Garantir que há imagens suficientes
if len(images) < 3:
    raise ValueError("O diretório de origem não contém imagens suficientes para dividir.")

# Divisão em treino, validação e teste
train_files, temp_files = train_test_split(images, train_size=train_ratio, random_state=42)
validation_files, test_files = train_test_split(temp_files, test_size=test_ratio / (validation_ratio + test_ratio), random_state=42)

# Função para mover arquivos para o diretório apropriado
def move_files(file_list, destination_dir):
    for file_name in file_list:
        source_path = os.path.join(source_dir, file_name)
        target_path = os.path.join(destination_dir, file_name)
        shutil.move(source_path, target_path)
        print(f"Arquivo '{file_name}' movido para '{destination_dir}'")

# Mover arquivos para os respectivos diretórios
move_files(train_files, train_dir)
move_files(validation_files, validation_dir)
move_files(test_files, test_dir)

print("Particionamento concluído.")

print("Treino:", len(train_files))
print("Validação:", len(validation_files))
print("Teste:", len(test_files))
# Out:
# Arquivo 'new2-1850.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1220.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-83.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-399.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1196.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1248.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-959.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-737.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1382.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2189.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-424.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-426.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-185.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2379.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1443.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1235.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-347.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-253.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-713.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new3-1417.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-3026.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1041.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-788.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-566.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-389.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1489.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2728.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1499.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1813.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-571.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1468.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1377.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1390.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-478.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-622.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-3090.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-532.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej3-7776.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1963.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1218.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-630.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-628.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1525.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-662.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-563.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-624.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-44.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-976.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-637.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-521.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej505.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-559.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new6.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-442.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-137.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1363.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-819.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2078.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1717.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1251.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-91.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-952.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1748.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-299.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-3019.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-954.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-456.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-578.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-808.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej503.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-3160.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1016.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-788.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1633.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1510.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-252.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1211.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new7.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1032.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-83.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1893.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-939.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-836.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-797.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1208.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-2087.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2309.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-907.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-582.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-524.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-456.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-981.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej3-8872.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1122.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1392.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-850.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-328.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej978.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-356.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-977.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-455.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej3-8322.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-453.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1201.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-384.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1142.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-99.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-284.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej504.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-943.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2050.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-180.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2324.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej512.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-340.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2497.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-839.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-728.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-338.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-233.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-581.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-97.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-908.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-828.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-750.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1201.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-769.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-372.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-364.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new9.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-144.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-466.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-506.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-451.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-526.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-891.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1308.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1548.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-910.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-881.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-304.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1390.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1735.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-425.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-525.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-528.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-211.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-527.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1428.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej3-7743.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-836.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1079.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-2872.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1836.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-691.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-127.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-739.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-1682.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-493.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-221.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2069.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1967.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-71.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-346.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2159.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-381.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-2141.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej373.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1119.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-944.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-564.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-991.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new3-1235.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-33.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-2240.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new3-1382.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-878.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-517.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-463.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-239.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-2593.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-88.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-12.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-3458.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2540.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-936.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-1791.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-485.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1288.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1577.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-411.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-3358.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-644.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-446.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-476.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2602.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-309.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-683.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-402.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-66.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-2123.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1267.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-2745.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-991.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-236.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-967.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1640.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-910.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-297.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-144.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1372.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-614.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1229.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1373.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1928.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1452.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1256.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-993.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1568.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-67.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-448.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-805.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-290.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-573.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-890.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-796.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-617.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-935.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1022.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-173.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-994.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2472.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-921.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1313.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-313.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1154.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-303.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1746.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-84.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1946.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2466.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-2876.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-349.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-470.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-947.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1264.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-270.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-87.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-665.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-987.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-382.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1111.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1385.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1478.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej346.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-2221.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1852.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-574.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-2506.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-30.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej356.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-484.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-280.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1357.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-1527.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2605.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-733.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-512.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-403.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej3-8833.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-132.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1339.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-715.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-3081.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2486.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-711.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-208.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-929.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-159.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-1734.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-691.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2550.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-564.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-293.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-356.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-832.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-687.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-2080.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej335.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1514.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1985.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-515.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1319.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1349.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-296.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1391.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1883.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-851.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej3-8194.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1919.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1841.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-2206.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1047.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-1798.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-312.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-616.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1316.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-849.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-724.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-501.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-818.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-1728.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1487.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-813.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1643.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1693.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1295.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1395.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-853.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2193.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-51.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-3.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-3477.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-1401.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-2071.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-503.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-408.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-840.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2015.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-909.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1647.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-868.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1371.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-211.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-2871.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-336.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-344.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-3490.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-104.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1962.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-214.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej406.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-324.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej388.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-197.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-951.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-743.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-997.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-393.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-561.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-7.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1744.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-702.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-666.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-65.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2255.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-600.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-124.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1441.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-394.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-1677.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1299.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej3-8813.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1802.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-2223.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-557.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej343.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-571.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1045.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-656.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-502.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new2-1570.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-983.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-487.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2577.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej3-8980.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new4-990.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1753.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-138.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-366.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1147.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-440.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-111.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-73.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-2697.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1863.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-83.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-380.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-720.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'new1-526.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-392.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new3-1888.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1874.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'angus_lej975.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-109.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-697.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_new2-145.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-1232.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'simmental_new5-419.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new4-1228.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'holstein_new3-88.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# Arquivo 'charolais_nuevo.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/train'
# ...
# Arquivo 'charolais_new3-1062.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'simmental_new4-28.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new3-2252.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new3-1144.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'simmental_new5-716.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new4-1007.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new4-437.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new3-649.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new3-1216.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new2-325.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new3-2282.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new3-1115.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'simmental_new5-1316.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'simmental_new5-2641.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new1-1371.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new2-2734.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new1-579.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new4-521.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new3-1051.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new2-134.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new2-628.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new3-609.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new3-345.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new3-73.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'simmental_new5-1821.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new3-880.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new1-856.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'angus_lej3-7849.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new2-1588.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new3-2157.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'simmental_new4-549.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new2-124.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new3-475.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'simmental_new5-863.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new4-1053.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'angus_lej3-8507.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'simmental_new5-2109.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'angus_lej3-8942.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'angus_lej3-8360.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new2-2749.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'holstein_new4-516.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new1-1492.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'charolais_new3-2408.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/validation'
# Arquivo 'new2-25.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-478.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new4-520.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-1672.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new2-2527.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-2474.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-416.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new2-1949.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-106.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_nuevo2.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new4-98.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new2-15.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-1008.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-394.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-748.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-1199.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-1726.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new2-3342.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-404.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-647.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'angus_lej3-8885.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new3-1340.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-860.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-63.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-313.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-2088.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-797.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-781.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'angus_lej375.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-1416.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new3-798.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-265.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-1254.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-98.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-1898.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-1198.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new3-1222.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-264.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-1069.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-21.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-992.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-1270.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-803.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new2-1528.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-604.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-813.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-2475.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-1225.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-328.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-1393.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-1457.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-1103.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-1946.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_nuevo3.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new3-390.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-1087.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-999.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-79.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-1699.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-665.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-2692.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new3-8.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new3-723.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-1076.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new2-3140.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-1210.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-2256.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-812.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-2393.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-1280.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new2-2976.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'angus_lej3-8839.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new2-3068.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-872.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-685.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new2-1252.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-697.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-1023.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new5-1313.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-751.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-532.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new2-312.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-804.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'new1-1580.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'simmental_new4-672.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-1308.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'angus_lej403.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-1992.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'charolais_new3-1593.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Arquivo 'holstein_new4-380.jpg' movido para '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/Taurinos/test'
# Particionamento concluído.
# Treino: 420
# Validação: 90
# Teste: 90

# %%
import sys
from matplotlib import pyplot as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import os


# NO CASO ESTÁ IMPORTANDO A CNN VGG16. CONSULTA NA INTERNET tensorflow.keras.applications
# POIS HÁ VARIAS OUTRAS CNNS QUE VC PODE TESTAR.
from tensorflow.keras.applications import VGG16, VGG19, ResNet152V2, DenseNet121, EfficientNetB0, EfficientNetB7

# %% [markdown]
# Monta o Google Drive

# %%
# define cnn model using VGG16
def define_model(num_classes, input_shape):

    # PARA TESTAR OUTRAS CNNS, ALÉM DA ALTERAÇÃO DA IMPORTAÇÃO DESSA ACIMA,
    # VC VAI TROCAR VGG16 PELO NOME DA CNN IMPORTADA

    # Load the VGG16 model, excluding the top (fully connected) layers
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze the layers in the base model
    for layer in base_model.layers:
        layer.trainable = False

    # Create a new model
    model = Sequential()
    # Add the VGG16 base model
    model.add(base_model)
    # Flatten the output from the base model
    model.add(Flatten())
    # Add new fully connected layers
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.2))
    # Output layer with num_classes units and sigmoid activation
    model.add(Dense(2, activation='softmax'))  # Saída: 1 neurônio
    #model.add(Dense(88, activation='softmax'))

    # Compile the model with categorical crossentropy for multi-class classification
    opt = SGD(learning_rate=0.001, momentum=0.9)
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# plot diagnostic learning curves
def summarize_diagnostics(history):
    # plot loss
    plt.subplot(211)
    plt.title('Cross Entropy Loss')
    plt.plot(history.history['loss'], color='blue', label='train')
    plt.plot(history.history['val_loss'], color='orange', label='test')
    # plot accuracy
    plt.subplot(212)
    plt.title('Classification Accuracy')
    plt.plot(history.history['accuracy'], color='blue', label='train')
    plt.plot(history.history['val_accuracy'], color='orange', label='test')
    # save plot to file
    filename = sys.argv[0].split('/')[-1]
    plt.savefig(filename + '_plot.png')
    plt.close()

# Funcao principal
def funcao_principal(num_classes, base_path, input_shape):
    # chama a função que define o modelo da rede
    model = define_model(num_classes, input_shape)

    # cria o gerador de dados de treino fazendo a normalização dos valores de pixels na escala real [0,1] e tirando 30% das amostras para validacao
    datagen_train = ImageDataGenerator(rescale=1.0/255.0, validation_split=0.15)

    # cria o gerador de dados de teste fazendo a normalização dos valores de pixels na escala real [0,1]
    datagen_test = ImageDataGenerator(rescale=1.0/255.0)

    # prepara os iteradores
    batch_size = 32

    # SE VOCÊ TIVER COM CONTA COLAB PRO, O CERTO É ZIPAR, BAIXAR E DESCOMPACTAR OS ARQUIVOS PARA A MAQUINA.
    # PELO Drive O ACESSO É LENTO
    train_it = datagen_train.flow_from_directory(os.path.join(base_path, 'train'),
        class_mode='categorical', batch_size=batch_size, target_size=(200, 200))

    validation_it = datagen_train.flow_from_directory(os.path.join(base_path, 'validation'),
        class_mode='categorical', batch_size=batch_size, target_size=(200, 200))

    test_it = datagen_test.flow_from_directory(os.path.join(base_path,'test'),
        class_mode='categorical', target_size=(200, 200))

    # fit model
    history = model.fit(train_it, validation_data=validation_it,
        validation_steps=validation_it.samples//batch_size, epochs=15, verbose=2)

# %% [markdown]
# Chama a função principal

# %%
# Aciona o programa
input_shape = (200, 200, 3)
epochs = 15


base_path  = '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/'


nclasses = len([name for name in os.listdir(os.path.join(base_path, 'train')) if os.path.isdir(os.path.join(base_path, 'train'))])

print(nclasses)

funcao_principal(nclasses, base_path, input_shape)
# Out:
# 2
# Found 463 images belonging to 2 classes.
# Found 103 images belonging to 2 classes.
# Found 98 images belonging to 2 classes.
# Epoch 1/15
# 15/15 - 259s - 17s/step - accuracy: 0.5227 - loss: 0.7502 - val_accuracy: 0.6042 - val_loss: 0.6429
# Epoch 2/15
# 15/15 - 278s - 19s/step - accuracy: 0.5616 - loss: 0.6552 - val_accuracy: 1.0000 - val_loss: 0.4520
# Epoch 3/15
# 15/15 - 302s - 20s/step - accuracy: 0.6890 - loss: 0.5835 - val_accuracy: 0.7396 - val_loss: 0.5738
# Epoch 4/15
# 15/15 - 218s - 15s/step - accuracy: 0.6782 - loss: 0.5874 - val_accuracy: 0.7143 - val_loss: 0.6782
# Epoch 5/15

# %%
##Se já treinou o modelo e o salvou como vgg16_cattle.keras, pode carregá-lo assim:

from tensorflow.keras.models import load_model

# Carregar o modelo salvo
model = load_model("/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/vgg16_cattle.keras")

# Exibir um resumo do modelo para verificar a arquitetura
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Model: "functional_73"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_23 (InputLayer)          │ (None, 200, 200, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 200, 200, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 200, 200, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 100, 100, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 100, 100, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 100, 100, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 50, 50, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 50, 50, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 50, 50, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 50, 50, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 25, 25, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 25, 25, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 25, 25, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 25, 25, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 12, 12, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 12, 12, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 12, 12, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 12, 12, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_18 (Flatten)                 │ (None, 18432)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 32)                  │         589,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_18 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_37 (Dense)                     │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 16,484,456 (62.88 MB)
#  Trainable params: 589,922 (2.25 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
#  Optimizer params: 1,179,846 (4.50 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Caminho para salvar o modelo
checkpoint_path = "/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/vgg16_cattle.keras"

# Criar o callback
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,          # Caminho do arquivo
    monitor='val_loss',                # Métrica a ser monitorada
    save_best_only=True,               # Salva apenas o melhor modelo
    save_weights_only=False,           # Salva todo o modelo, não apenas os pesos
    mode='min',                        # Menor val_loss é melhor
    verbose=2                          # Mostra logs de salvamento
)

# Usar o callback durante o treinamento
history = model.fit(
    train_it,
    validation_data=validation_it,
    epochs=15,
    callbacks=[checkpoint]             # Adicione o callback aqui
)

# %%
##Se você está usando a VGG16 com Transfer Learning, pode carregar a arquitetura base do modelo e ajustar as camadas finais para o seu problema:

from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout

# Carregar a base do modelo VGG16 pré-treinada no ImageNet
base_model = VGG16(weights="imagenet", include_top=False, input_shape=(200, 200, 3))

# Congelar as camadas da base
for layer in base_model.layers:
    layer.trainable = False

# Adicionar camadas personalizadas
x = Flatten()(base_model.output)
x = Dense(32, activation='relu')(x)
x = Dropout(0.2)(x)
output = Dense(2, activation='softmax')(x)  # Alterar o número de classes conforme necessário

# Construir o modelo final
model = Model(inputs=base_model.input, outputs=output)

# Compilar o modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Exibir o resumo
model.summary()
model.save("/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/vgg16_cattle.keras")

# Avaliar no conjunto de teste
loss, accuracy = model.evaluate(test_it, verbose=2)
print(f"Loss: {loss}, Accuracy: {accuracy}")
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 200, 200, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 200, 200, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 200, 200, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 100, 100, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 100, 100, 128)       │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 100, 100, 128)       │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 50, 50, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 50, 50, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 50, 50, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 50, 50, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 25, 25, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 25, 25, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 25, 25, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 25, 25, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 12, 12, 512)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 12, 12, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 12, 12, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 12, 12, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 6, 6, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 18432)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │         589,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,304,610 (58.38 MB)
#  Trainable params: 589,922 (2.25 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-499505b28e83> in <cell line: 31>()
#      29
#      30 # Avaliar no conjunto de teste
# ---> 31 loss, accuracy = model.evaluate(test_it, verbose=2)
#      32 print(f"Loss: {loss}, Accuracy: {accuracy}")
#
# NameError: name 'test_it' is not defined

# %% [markdown]
# Avalia o Modelo

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

base_path = '/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/Images/'
model_name = "/content/drive/MyDrive/IA_ciencia_animal/TrabalhoIA/vgg16_cattle.keras"

# cria o gerador de dados de teste fazendo a normalização dos valores de pixels na escala real [0,1]
datagen_test = keras.preprocessing.image.ImageDataGenerator(rescale=1.0 / 255.0)

test_it = datagen_test.flow_from_directory(
    os.path.join(base_path, 'test'),
    class_mode='categorical',
    target_size=(200, 200),
    shuffle=False  # Importante para manter as classes alinhadas
)

model = keras.models.load_model(os.path.join(base_path, model_name))

# Avalia o modelo
loss, accuracy, precision, recall, f1_score = model.evaluate(test_it, verbose=2)

print(f"Perda: {loss:.3f}")
print(f"Acurácia: {accuracy * 100.0:.3f}%")
print(f"Precisão: {precision * 100.0:.3f}")
print(f"Revocação: {recall * 100.0:.3f}")

# Obter as previsões do modelo
predictions = model.predict(test_it, verbose=2)

# A classe verdadeira de cada imagem
true_classes = test_it.classes

# Obter as previsões como uma classe, ou seja, o índice da classe com a maior probabilidade
predicted_classes = np.argmax(predictions, axis=1)

# Calcular a matriz de confusão com TensorFlow
conf_matrix_tf = tf.math.confusion_matrix(
    labels=true_classes,
    predictions=predicted_classes
).numpy()

print(conf_matrix_tf)

# Mostrar a matriz de confusão com o seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_tf, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_it.class_indices.keys(),
            yticklabels=test_it.class_indices.keys())
plt.title('Matriz de Confusão (TensorFlow)')
plt.xlabel('Classe Predita')
plt.ylabel('Classe Verdadeira')
plt.show()
# Out:
# Found 110 images belonging to 2 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'adam', because it has 10 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 4/4 - 51s - 13s/step - accuracy: 0.5273 - loss: 0.7554
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-0b61639667ae> in <cell line: 24>()
#      22
#      23 # Avalia o modelo
# ---> 24 loss, accuracy, precision, recall, f1_score = model.evaluate(test_it, verbose=2)
#      25
#      26 print(f"Perda: {loss:.3f}")
#
# ValueError: not enough values to unpack (expected 5, got 2)
